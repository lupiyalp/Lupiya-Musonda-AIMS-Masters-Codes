# %% [markdown]
# # General parameters

# %%
import random
import time
import numpy as np
import matplotlib.pyplot as plt
print("""
 ______________
3|  |    |  |+1|
 --------------
2|  |wall|  |-1|
 --------------
1|  |    |  |  |
 --------------
  1   2  3  4
""")
pass
# Out:
#  ______________
# 3|  |    |  |+1|
#  --------------
# 2|  |wall|  |-1|
#  --------------
# 1|  |    |  |  |
#  --------------
#   1   2  3  4

# %%
#Rewards of all states, R is for the goal state, Rr is for the negative terminal state and r is for all other states
R,Rr,r=1,-1,0

# %%
States=[(1,1),(1,2),(1,3),(2,3),(2,1),(3,1),(3,2),(3,3),(4,1)]

# %%
Actions=['L','R','U','D']# The list of all possible actions

# %%
alpha=0.001 #learning rate
gamma=0.99  #discounting factor
epsilon=0.9 #exploration rate
epsilon_min=0.01

# %%
#ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]

# %%
N=30000

# %% [markdown]
# # $\varepsilon-Greedy$

# %%
def E_greedy1():
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    #N=50000
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode

       # print(S,A)
        while S!=(4,2) and S!=(4,3):

      #EXPLORATION ACTION
            if random.uniform(0,1)>1-epsilon:# exploration condition
                #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

                        
                        
            if random.uniform(0,1)<1-epsilon: #condition for exploitation

                #STATE(1,1)
                if S==(1,1):
                    c=ActionValues.index(max(ActionValues[:4])) #selecting the maximum action in state (1,1)
                    if c==0:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==1:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==2:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==3:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(1,1)

                #STATE(1,2)
                if S==(1,2):
                    c=ActionValues.index(max(ActionValues[4:8]))
                    if c==4:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                #STATE(1,3)
                if S==(1,3):
                    c=ActionValues.index(max(ActionValues[8:12]))
                    if c==8:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                #STATE(2,3)
                if S==(2,3):
                    c=ActionValues.index(max(ActionValues[12:16]))
                    if c==12:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==13:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==14:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==15:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                #STATE(2,1)
                if S==(2,1):
                    c=ActionValues.index(max(ActionValues[16:20]))
                    if c==16:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==17:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==18:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[c])
                        S=(1,1)

                    if c==19:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)


                #STATE(3,1)
                if S==(3,1):
                    c=ActionValues.index(max(ActionValues[20:24]))
                    if c==20:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==21:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==22:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==22:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(4,1)


                #STATE(3,2)
                if S==(3,2):
                    c=ActionValues.index(max(ActionValues[24:28]))
                    if c==24:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==25:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==26:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==27:#right
                        # the q values of terminal states are all 0's
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                #STATE(3,3)
                if S==(3,3):
                    c=ActionValues.index(max(ActionValues[28:32]))
                    if c==28:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==29:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==30:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==31:#right
                        ActionValues[c]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,1)


                #STATE(4,1)
                if S==(4,1):
                    c=ActionValues.index(max(ActionValues[32:]))
                    if c==32:#up
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                    if c==33:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)

                    if c==34:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==35:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)
        
                        
                

    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return ActionValues

# %%
t=E_greedy1()
# Out:
# Runtime of the program is 3.187650442123413

# %%
def E_greedy2():
    #N=50000
    #epsilon=0.9
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    sum_mse=[]
    #ss.append(sum_mse)
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode
        
       # print(S,A)
        while S!=(4,2) and S!=(4,3):
                #finding the sum squared error to come up with 1 plot from 36 different Q-values
            sum_mse.append(((ActionValues[0]-t[0])**2+(ActionValues[1]-t[1])**2+(ActionValues[2]-t[2])**2+(ActionValues[3]-t[3])**2
    +(ActionValues[4]-t[4])**2+(ActionValues[5]-t[5])**2+(ActionValues[6]-t[6])**2+(ActionValues[7]-t[7])**2
    +(ActionValues[8]-t[8])**2+(ActionValues[9]-t[9])**2+(ActionValues[10]-t[10])**2+(ActionValues[11]-t[11])**2
    +(ActionValues[12]-t[12])**2+(ActionValues[3]-t[13])**2+(ActionValues[14]-t[14])**2+(ActionValues[15]-t[15])**2
    +(ActionValues[16]-t[16])**2+(ActionValues[17]-t[17])**2+(ActionValues[18]-t[18])**2+(ActionValues[19]-t[19])**2
    +(ActionValues[20]-t[20])**2+(ActionValues[21]-t[21])**2+(ActionValues[22]-t[22])**2+(ActionValues[23]-t[23])**2
    +(ActionValues[24]-t[24])**2+(ActionValues[25]-t[25])**2+(ActionValues[26]-t[26])**2+(ActionValues[27]-t[27])**2
    +(ActionValues[28]-t[28])**2+(ActionValues[29]-t[29])**2+(ActionValues[30]-t[30])**2+(ActionValues[31]-t[31])**2
    +(ActionValues[32]-t[32])**2+(ActionValues[33]-t[33])**2+(ActionValues[34]-t[34])**2+(ActionValues[35]-t[35])**2
    ))





      #EXPLORATION ACTION
            if random.uniform(0,1)>1-epsilon:# exploration condition
                #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

                        
                        
            if random.uniform(0,1)<1-epsilon: #condition for exploitation

                #STATE(1,1)
                if S==(1,1):
                    c=ActionValues.index(max(ActionValues[:4])) #selecting the maximum action in state (1,1)
                    if c==0:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==1:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==2:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==3:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(1,1)

                #STATE(1,2)
                if S==(1,2):
                    c=ActionValues.index(max(ActionValues[4:8]))
                    if c==4:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                #STATE(1,3)
                if S==(1,3):
                    c=ActionValues.index(max(ActionValues[8:12]))
                    if c==8:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                #STATE(2,3)
                if S==(2,3):
                    c=ActionValues.index(max(ActionValues[12:16]))
                    if c==12:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==13:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==14:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==15:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                #STATE(2,1)
                if S==(2,1):
                    c=ActionValues.index(max(ActionValues[16:20]))
                    if c==16:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==17:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==18:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[c])
                        S=(1,1)

                    if c==19:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)


                #STATE(3,1)
                if S==(3,1):
                    c=ActionValues.index(max(ActionValues[20:24]))
                    if c==20:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==21:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==22:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==22:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(4,1)


                #STATE(3,2)
                if S==(3,2):
                    c=ActionValues.index(max(ActionValues[24:28]))
                    if c==24:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==25:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==26:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==27:#right
                        # the q values of terminal states are all 0's
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                #STATE(3,3)
                if S==(3,3):
                    c=ActionValues.index(max(ActionValues[28:32]))
                    if c==28:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==29:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==30:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==31:#right
                        ActionValues[c]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,1)


                #STATE(4,1)
                if S==(4,1):
                    c=ActionValues.index(max(ActionValues[32:]))
                    if c==32:#up
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                    if c==33:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)

                    if c==34:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==35:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)
        
    #epsilon*=0.99
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return sum_mse

# %%
a0=E_greedy2() 
b0=E_greedy2()
c0=E_greedy2()
d0=E_greedy2()
e0=E_greedy2()
f0=E_greedy2()
g0=E_greedy2()
h0=E_greedy2()
i0=E_greedy2()
j0=E_greedy2()
# Out:
# Runtime of the program is 8.41389536857605
# Runtime of the program is 8.419498682022095
# Runtime of the program is 7.966533422470093
# Runtime of the program is 7.92869234085083
# Runtime of the program is 8.688900232315063
# Runtime of the program is 8.317620754241943
# Runtime of the program is 8.417495965957642
# Runtime of the program is 8.197129011154175
# Runtime of the program is 8.221243143081665
# Runtime of the program is 8.37797474861145

# %%
summ0 = []
#initialization of result list
zip_object0 = zip(a0,b0,c0,d0,e0,f0,g0,h0,i0,j0)
for a1,b1,c1,d1,e1,f1,g1,h1,i1,j1 in zip_object0:
    summ0.append((a1+b1+c1+d1+e1+f1+g1+h1+i1+j1))

avsum0=[(1/10)*i  for i in summ0]

x0=np.linspace(0,N,len(avsum0))

# %%
plt.plot(x0,avsum0,color="b",label=("Single Agent E-Greedy"))
plt.grid(color="k")
plt.legend()
plt.ylabel('Sum Squared Error (SSE)')
plt.xlabel('Episodes')
plt.title("Single Agent $\epsilon$-Greedy")
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 18

# %% [markdown]
# # 2. Exploration only

# %%
def Explore():
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    #N=50000
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode

       # print(S,A)
        while S!=(4,2) and S!=(4,3):

      #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return ActionValues

# %%
t=Explore()
# Out:
# Runtime of the program is 2.3214664459228516

# %%
def Explore1():
    #N=50000
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    sum_mse=[]
    #ss.append(sum_mse)
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode

       # print(S,A)
        while S!=(4,2) and S!=(4,3):
                #finding the sum squared error to come up with 1 plot from 36 different Q-values
                sum_mse.append(((ActionValues[0]-t[0])**2+(ActionValues[1]-t[1])**2+(ActionValues[2]-t[2])**2+(ActionValues[3]-t[3])**2
    +(ActionValues[4]-t[4])**2+(ActionValues[5]-t[5])**2+(ActionValues[6]-t[6])**2+(ActionValues[7]-t[7])**2
    +(ActionValues[8]-t[8])**2+(ActionValues[9]-t[9])**2+(ActionValues[10]-t[10])**2+(ActionValues[11]-t[11])**2
    +(ActionValues[12]-t[12])**2+(ActionValues[3]-t[13])**2+(ActionValues[14]-t[14])**2+(ActionValues[15]-t[15])**2
    +(ActionValues[16]-t[16])**2+(ActionValues[17]-t[17])**2+(ActionValues[18]-t[18])**2+(ActionValues[19]-t[19])**2
    +(ActionValues[20]-t[20])**2+(ActionValues[21]-t[21])**2+(ActionValues[22]-t[22])**2+(ActionValues[23]-t[23])**2
    +(ActionValues[24]-t[24])**2+(ActionValues[25]-t[25])**2+(ActionValues[26]-t[26])**2+(ActionValues[27]-t[27])**2
    +(ActionValues[28]-t[28])**2+(ActionValues[29]-t[29])**2+(ActionValues[30]-t[30])**2+(ActionValues[31]-t[31])**2
    +(ActionValues[32]-t[32])**2+(ActionValues[33]-t[33])**2+(ActionValues[34]-t[34])**2+(ActionValues[35]-t[35])**2
    ))





    #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return sum_mse

# %%
a1=Explore1() 
b1=Explore1()
c1=Explore1()
d1=Explore1()
e1=Explore1()
f1=Explore1()
g1=Explore1()
h1=Explore1()
i1=Explore1()
j1=Explore1()





summ1 = []
#initialization of result list
zip_object1 = zip(a1,b1,c1,d1,e1,f1,g1,h1,i1,j1)
for a1,b1,c1,d1,e1,f1,g1,h1,i1,j1 in zip_object1:
    summ1.append((a1+b1+c1+d1+e1+f1+g1+h1+i1+j1))

avsum1=[(1/10)*i  for i in summ1]
# Out:
# Runtime of the program is 7.470317840576172
# Runtime of the program is 7.708080768585205
# Runtime of the program is 7.994703531265259
# Runtime of the program is 7.3130412101745605
# Runtime of the program is 7.212286949157715
# Runtime of the program is 7.205601930618286
# Runtime of the program is 7.405075311660767
# Runtime of the program is 7.391000986099243
# Runtime of the program is 7.3568336963653564
# Runtime of the program is 7.393161773681641

# %%
x1=np.linspace(0,N,len(avsum1))

plt.plot(x1,avsum1,color="g",label=("Single exploring Agent"))
plt.grid(color="blue")
plt.ylabel('Sum Squared Error (SSE)')
plt.xlabel('Episodes')
plt.legend()
plt.title("Single Agent with Exploration only")
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 30

# %% [markdown]
# # 3. Double agent with exploration only (Unmodified)

# %%
def Double_Agents():
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    #N=50000
    start = time.time()
    for i in range(N):
        S1=random.choice(States) #initialising the statrting state for each episode
        S2=random.choice(States)
       # print(S,A)
        while S1!=(4,2) and S1!=(4,3) and S2!=(4,2) and S2!=(4,3):

      #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                #A1=random.choice(Actions)     #selecting a random action
                #A2=random.choice(Actions)
            A1=random.choice(Actions)
            A2=random.choice(Actions)
            #print(A1,A2)
            if S1==(1,1):
    ################################################3     (STATE 1,1)#################################3          
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:31])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(2,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)



        ##############S2=(4,1)#######################3
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
    #########################################    (STATE 1,2)    ##########################################################
            if S1==(1,2):
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)##############
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):###########################
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)



        ##############S2=(4,1)
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

    #####################################################      (STATE 1,3)          ##################################3#####################33
            if S1==(1,3):
                    if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                    if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          s1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                    if S2==(1,3):###########################
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          S2=(2,3)



            ##############S2=(2,3)
                    if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                    if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)
                    if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                    if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                    if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                    if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
#########################################    (STATE 2,3)########################################################
            if S1==(2,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          s1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        
#########################################   (STATE 1,2)    ##################################

            if S1==(2,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                            S1=(2,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                            S1=(1,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(r+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
################################   (STATE 3,1)     ##########################################################3#####

            if S1==(3,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                            S1=(2,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
                            
                            
##########################################     (STATE (3,2)) ##############################


            if S1==(3,2):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                            S1=(3,2)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
            


            if S1==(3,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                            S1=(3,2)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                            S1=(2,3)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)


###################################    (STATE (1,4))       #############################3                            
                            
        
            if S1==(4,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
            #############################################################################3
            ##############S2=(1,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                            S1=(4,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                            S1=(3,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          S2=(4,1)

                        
                        
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return ActionValues

# %%
t=Double_Agents()
# Out:
# Runtime of the program is 1.7509665489196777

# %%
def Double_Agents1():
    #N=50000
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    sum_mse=[]
    #ss.append(sum_mse)
    start = time.time()
    for i in range(N):
        S1=random.choice(States) #initialising the statrting state for each episode
        S2=random.choice(States)
       # print(S,A)
        while S1!=(4,2) and S1!=(4,3) and S2!=(4,2) and S2!=(4,3):
                #finding the sum squared error to come up with 1 plot from 36 different Q-values
            sum_mse.append(((ActionValues[0]-t[0])**2+(ActionValues[1]-t[1])**2+(ActionValues[2]-t[2])**2+(ActionValues[3]-t[3])**2
    +(ActionValues[4]-t[4])**2+(ActionValues[5]-t[5])**2+(ActionValues[6]-t[6])**2+(ActionValues[7]-t[7])**2
    +(ActionValues[8]-t[8])**2+(ActionValues[9]-t[9])**2+(ActionValues[10]-t[10])**2+(ActionValues[11]-t[11])**2
    +(ActionValues[12]-t[12])**2+(ActionValues[3]-t[13])**2+(ActionValues[14]-t[14])**2+(ActionValues[15]-t[15])**2
    +(ActionValues[16]-t[16])**2+(ActionValues[17]-t[17])**2+(ActionValues[18]-t[18])**2+(ActionValues[19]-t[19])**2
    +(ActionValues[20]-t[20])**2+(ActionValues[21]-t[21])**2+(ActionValues[22]-t[22])**2+(ActionValues[23]-t[23])**2
    +(ActionValues[24]-t[24])**2+(ActionValues[25]-t[25])**2+(ActionValues[26]-t[26])**2+(ActionValues[27]-t[27])**2
    +(ActionValues[28]-t[28])**2+(ActionValues[29]-t[29])**2+(ActionValues[30]-t[30])**2+(ActionValues[31]-t[31])**2
    +(ActionValues[32]-t[32])**2+(ActionValues[33]-t[33])**2+(ActionValues[34]-t[34])**2+(ActionValues[35]-t[35])**2
    ))





    #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                #A1=random.choice(Actions)     #selecting a random action
                #A2=random.choice(Actions)
            #A1=random.choice(Actions)
            #A2=random.choice(Actions)

            A1=random.choice(Actions)
            A2=random.choice(Actions)
            #print(A1,A2)
            if S1==(1,1):
    ################################################3     (STATE 1,1)#################################3          
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:31])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(2,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)



        ##############S2=(4,1)#######################3
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
    #########################################    (STATE 1,2)    ##########################################################
            if S1==(1,2):
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)##############
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):###########################
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=(4,2)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=(4,3)



        ##############S2=(4,1)
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=(4,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

    #####################################################      (STATE 1,3)          ##################################3#####################33
            if S1==(1,3):
                    if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                    if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          s1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                    if S2==(1,3):###########################
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          S2=(2,3)



            ##############S2=(2,3)
                    if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                    if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)
                    if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                    if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                    if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                    if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
#########################################    (STATE 2,3)########################################################
            if S1==(2,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          s1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        
#########################################   (STATE 1,2)    ##################################

            if S1==(2,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                            S1=(2,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                            S1=(1,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(r+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
################################   (STATE 3,1)     ##########################################################3#####

            if S1==(3,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                            S1=(2,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
                            
                            
##########################################     (STATE (3,2)) ##############################


            if S1==(3,2):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                            S1=(3,2)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
            


            if S1==(3,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                            S1=(3,2)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                            S1=(2,3)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)


###################################    (STATE (1,4))       #############################3                            
                            
        
            if S1==(4,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
            #############################################################################3
            ##############S2=(1,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                            S1=(4,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                            S1=(3,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=(4,3)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          S2=(4,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          S2=(4,1)

                        
                        
                        
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return sum_mse

# %%
a2=Double_Agents1() 
b2=Double_Agents1()
c2=Double_Agents1()
d2=Double_Agents1()
e2=Double_Agents1()
f2=Double_Agents1()
g2=Double_Agents1()
h2=Double_Agents1()
i2=Double_Agents1()
j2=Double_Agents1()
# Out:
# Runtime of the program is 2.782058000564575
# Runtime of the program is 2.6535444259643555
# Runtime of the program is 2.7584502696990967
# Runtime of the program is 2.6511809825897217
# Runtime of the program is 2.75527024269104
# Runtime of the program is 2.73579740524292
# Runtime of the program is 2.724578619003296
# Runtime of the program is 2.6910533905029297
# Runtime of the program is 2.8895885944366455
# Runtime of the program is 2.8913817405700684

# %%
summ2 = []
#initialization of result list
zip_object2 = zip(a2,b2,c2,d2,e2,f2,g2,h2,i2,j2)
for a1,b1,c1,d1,e1,f1,g1,h1,i1,j1 in zip_object2:
    summ2.append((a1+b1+c1+d1+e1+f1+g1+h1+i1+j1))

# %%
avsum2=[(1/10)*i for i in summ2]

# %%
x2=np.linspace(0,N,len(avsum2))

# %%
plt.plot(x2,avsum2,color="r",label="Double Exploring Agents(Unmodified)")
plt.legend()
plt.grid(color="k")
plt.ylabel('Sum Squared Error (SSE)')
plt.xlabel('Episodes')
plt.title("Double Agent setting with both agents having power to end an episode")
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 18

# %% [markdown]
# # Double Agents with modification of only Agent1 has the power to end an epsiode

# %%
def Double_Agent_Modified():
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    #N=50000
    start = time.time()
    for i in range(N):
        S1=random.choice(States) #initialising the statrting state for each episode
        S2=random.choice(States)
       # print(S,A)
        while S1!=(4,2) and S1!=(4,3) and S2!=(4,2) and S2!=(4,3):

      #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                #A1=random.choice(Actions)     #selecting a random action
                #A2=random.choice(Actions)
            A1=random.choice(Actions)
            A2=random.choice(Actions)
            #print(A1,A2)
            if S1==(1,1):
    ################################################3     (STATE 1,1)#################################3          
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:31])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(2,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)



        ##############S2=(4,1)#######################3
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
    #########################################    (STATE 1,2)    ##########################################################
            if S1==(1,2):
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)##############
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):###########################
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)



        ##############S2=(4,1)
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

    #####################################################      (STATE 1,3)          ##################################3#####################33
            if S1==(1,3):
                    if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                    if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          s1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                    if S2==(1,3):###########################
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          S2=(2,3)



            ##############S2=(2,3)
                    if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                    if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)
                    if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                    if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                    if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                    if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
#########################################    (STATE 2,3)########################################################
            if S1==(2,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          s1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        
#########################################   (STATE 1,2)    ##################################

            if S1==(2,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                            S1=(2,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                            S1=(1,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(r+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
################################   (STATE 3,1)     ##########################################################3#####

            if S1==(3,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                            S1=(2,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
                            
                            
##########################################     (STATE (3,2)) ##############################


            if S1==(3,2):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                            S1=(3,2)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
            


            if S1==(3,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                            S1=(3,2)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                            S1=(2,3)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)


###################################    (STATE (1,4))       #############################3                            
                            
        
            if S1==(4,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
            #############################################################################3
            ##############S2=(1,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                            S1=(4,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                            S1=(3,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          S2=(4,1)

                        
                        
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return ActionValues

# %%
t=Double_Agent_Modified()
# Out:
# Runtime of the program is 2.4157276153564453

# %%
def Double_Agents_Modified1():
    #N=50000
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    sum_mse=[]
    #ss.append(sum_mse)
    start = time.time()
    for i in range(N):
        S1=random.choice(States) #initialising the statrting state for each episode
        S2=random.choice(States)
       # print(S,A)
        while S1!=(4,2) and S1!=(4,3) and S2!=(4,2) and S2!=(4,3):
                #finding the sum squared error to come up with 1 plot from 36 different Q-values
            sum_mse.append(((ActionValues[0]-t[0])**2+(ActionValues[1]-t[1])**2+(ActionValues[2]-t[2])**2+(ActionValues[3]-t[3])**2
    +(ActionValues[4]-t[4])**2+(ActionValues[5]-t[5])**2+(ActionValues[6]-t[6])**2+(ActionValues[7]-t[7])**2
    +(ActionValues[8]-t[8])**2+(ActionValues[9]-t[9])**2+(ActionValues[10]-t[10])**2+(ActionValues[11]-t[11])**2
    +(ActionValues[12]-t[12])**2+(ActionValues[3]-t[13])**2+(ActionValues[14]-t[14])**2+(ActionValues[15]-t[15])**2
    +(ActionValues[16]-t[16])**2+(ActionValues[17]-t[17])**2+(ActionValues[18]-t[18])**2+(ActionValues[19]-t[19])**2
    +(ActionValues[20]-t[20])**2+(ActionValues[21]-t[21])**2+(ActionValues[22]-t[22])**2+(ActionValues[23]-t[23])**2
    +(ActionValues[24]-t[24])**2+(ActionValues[25]-t[25])**2+(ActionValues[26]-t[26])**2+(ActionValues[27]-t[27])**2
    +(ActionValues[28]-t[28])**2+(ActionValues[29]-t[29])**2+(ActionValues[30]-t[30])**2+(ActionValues[31]-t[31])**2
    +(ActionValues[32]-t[32])**2+(ActionValues[33]-t[33])**2+(ActionValues[34]-t[34])**2+(ActionValues[35]-t[35])**2
    ))





    #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                #A1=random.choice(Actions)     #selecting a random action
                #A2=random.choice(Actions)
            A1=random.choice(Actions)
            A2=random.choice(Actions)
            #print(A1,A2)
            if S1==(1,1):
    ################################################3     (STATE 1,1)#################################3          
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:31])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(2,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)



        ##############S2=(4,1)#######################3
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="U" and A2=="D":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="D" and A2=="D":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="L" and A2=="D":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="R" and A2=="D":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S1=(2,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
    #########################################    (STATE 1,2)    ##########################################################
            if S1==(1,2):
                if S2==(1,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                      S2=(2,1)
                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(2,1)
                      ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                      S2=(1,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                      S2=(2,1)
        ###########
                if S2==(1,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      S2=(1,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)##############
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      S2=(1,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S2=(1,2)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S2=(1,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S2=(1,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      S2=(1,2)

        ##############S2=(1,3)
                if S2==(1,3):###########################
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="D" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S2=(1,2)
                    if A1=="D" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,1)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                      S2=(1,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                      S2=(1,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                      S2=(2,3)



        ##############S2=(2,3)
                if S2==(2,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                      S2=(2,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                      S2=(3,3)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                      S2=(2,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                      S2=(2,3)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                      S2=(1,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                      S2=(3,3)



        ##############S2=(2,1)
                if S2==(2,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(2,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                      S2=(2,1)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                      S2=(2,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                      S2=(1,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                      S2=(3,1)


        ##############S2=(3,1)
                if S2==(3,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(3,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                      S2=(3,2)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                      S2=(2,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                      S2=(4,1)



        ##############S2=(3,2)
                if S2==(3,2):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                      S2=(3,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                      S2=(3,2)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                      S2=random.choice(States)



        ##############S2=(3,3)
                if S2==(3,3):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                      S2=(3,3)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                      S2=(3,2)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                      S2=(2,3)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                      S2=random.choice(States)



        ##############S2=(4,1)
                if S2==(4,1):
                    #A1==UP
                    if A1=="U" and A2=="U":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="U" and A2=="D":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="U" and A2=="L":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="U" and A2=="R":
                      ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                      S1=(1,3)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                      S2=(4,1)
                    #A1==DOWN
                    if A1=="D" and A2=="U":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="D" and A2=="D":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="D" and A2=="L":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="D" and A2=="R":
                      ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                      S1=(1,1)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)
                    #A1==LEFT
                    if A1=="L" and A2=="U":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="L" and A2=="D":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="L" and A2=="L":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="L" and A2=="R":
                      ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

                    #A1==RIGHT
                    if A1=="R" and A2=="U":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                      S2=random.choice(States)
                    if A1=="R" and A2=="D":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                      S2=(4,1)
                    if A1=="R" and A2=="L":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                      S2=(3,1)
                    if A1=="R" and A2=="R":
                      ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                      S1=(1,2)
                      ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                      S2=(4,1)

    #####################################################      (STATE 1,3)          ##################################3#####################33
            if S1==(1,3):
                    if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                    if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          s1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                    if S2==(1,3):###########################
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          S2=(2,3)



            ##############S2=(2,3)
                    if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                    if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)
                    if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                    if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                    if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                    if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S1=(1,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
#########################################    (STATE 2,3)########################################################
            if S1==(2,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          s1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                            S1=(3,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[26:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S1=(1,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        
#########################################   (STATE 1,2)    ##################################

            if S1==(2,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          s1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                            S1=(3,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)



            ##############S2=(2,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                            S1=(2,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                            S1=(1,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(r+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S1=(1,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=(4,2)
                        if A1=="R" and A2=="D":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
################################   (STATE 3,1)     ##########################################################3#####

            if S1==(3,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          s1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)##############
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                            S1=(2,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          S1=(2,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=(4,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[20])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                            
                            
                            
                            
##########################################     (STATE (3,2)) ##############################


            if S1==(3,2):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S1=(2,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                            S1=(4,2)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                            S1=(3,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                            S1=(3,2)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
            


            if S1==(3,3):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          s1=(3,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

            ##############S2=(1,3)
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                            S1=(4,3)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                            S1=(3,2)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                            S1=(2,3)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S1=(3,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S1=(3,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S1=(2,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S1=(4,3)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)


###################################    (STATE (1,4))       #############################3                            
                            
        
            if S1==(4,1):
                      if S2==(1,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                          S2=(2,1)
                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0])
                          S2=(1,1)
                        if A1=="R" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[1]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[1])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[2])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[2]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[2])
                          S2=(2,1)
            ###########HEERE
                      if S2==(1,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          s1=(4,2)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[5]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[5])
                          S2=(1,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                          S2=(1,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                          S2=(1,2)
            #############################################################################3
            ##############S2=(1,3)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
                      if S2==(1,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[4]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[4])
                          S2=(1,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                          S2=(1,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                          S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                          S2=(2,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                          S2=(1,3)
                        if A1=="R" and A2=="D":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                            S2=(1,2)
                        if A1=="R" and A2=="L":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                            S2=(1,3)
                        if A1=="R" and A2=="R":
                            ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                            S1=(4,1)
                            ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                            S2=(2,3)


            ##############S2=(2,3)
                      if S2==(2,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="D" and A2=="D":
                            ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                            S1=(4,1)  
                            ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                            S2=(2,3)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                          S2=(2,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="L" and A2=="L":
                            ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                            S1=(3,1)
                            ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                            S2=(1,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[14])
                          S2=(3,3)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[12]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[12])
                          S2=(2,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                          S2=(2,3)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                          S2=(1,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                          S2=(3,3)



            ##############S2=(2,1)
                      if S2==(2,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          s2=(1,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(2,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                          S2=(2,1)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                          S2=(2,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[18]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[18])
                          S2=(1,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                          S2=(3,1)


            ##############S2=(3,1)HEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                      if S2==(3,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(3,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[21])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                          S2=(3,2)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                          S2=(2,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                          S2=(4,1)



            ##############S2=(3,2)
                      if S2==(3,2):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[25])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==D
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:30])-ActionValues[24])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])
                          S2=(3,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])
                          S2=(3,2)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])
                          S2=random.choice(States)



            ##############S2=(3,3)
                      if S2==(3,3):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="U" and A2=="D":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="U" and A2=="L":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="U" and A2=="R":
                          ActionValues[33]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[33])
                          S1=(4,2)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])
                          S2=(3,3)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])
                          S2=(3,2)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])
                          S2=(2,3)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                          S2=random.choice(States)



            ##############S2=(4,1)
                      if S2==(4,1):
                        #A1==UP
                        if A1=="U" and A2=="U":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          S2=random.choice(States)
                        if A1=="U" and A2=="D":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="U" and A2=="L":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="U" and A2=="R":
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S1=(4,2)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])######
                          S2=random.choice(States)
                        #A1==DOWN
                        if A1=="D" and A2=="U":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="D" and A2=="D":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          S2=(4,1)
                        if A1=="D" and A2=="L":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="D" and A2=="R":
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S1=(4,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)
                        #A1==LEFT
                        if A1=="L" and A2=="U":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="L" and A2=="D":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="L" and A2=="L":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          S2=(3,1)
                        if A1=="L" and A2=="R":
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S1=(3,1)
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S2=(4,1)

                        #A1==RIGHT
                        if A1=="R" and A2=="U":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                          S2=random.choice(States)
                        if A1=="R" and A2=="D":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                          S2=(4,1)
                        if A1=="R" and A2=="L":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])
                          S2=(3,1)
                        if A1=="R" and A2=="R":
                          ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])
                          S1=(4,1)
                          S2=(4,1)

                        
                        
                        
                        
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return sum_mse

# %%
a3=Double_Agents_Modified1() 
b3=Double_Agents_Modified1()
c3=Double_Agents_Modified1()
d3=Double_Agents_Modified1()
e3=Double_Agents_Modified1()
f3=Double_Agents_Modified1()
g3=Double_Agents_Modified1()
h3=Double_Agents_Modified1()
i3=Double_Agents_Modified1()
j3=Double_Agents_Modified1()
# Out:
# Runtime of the program is 4.1290013790130615
# Runtime of the program is 3.8961687088012695
# Runtime of the program is 3.924285650253296
# Runtime of the program is 3.9498119354248047
# Runtime of the program is 3.9643044471740723
# Runtime of the program is 3.9880428314208984
# Runtime of the program is 4.025525808334351
# Runtime of the program is 3.9268417358398438
# Runtime of the program is 3.975433588027954
# Runtime of the program is 4.16060209274292

# %%
summ3 = []
#initialization of result list
zip_object3 = zip(a3,b3,c3,d3,e3,f3,g3,h3,i3,j3)
for a1,b1,c1,d1,e1,f1,g1,h1,i1,j1 in zip_object3:
    summ3.append((a1+b1+c1+d1+e1+f1+g1+h1+i1+j1))

avsum3=[(1/10)*i  for i in summ3]

# %%
x3=np.linspace(0,N,len(avsum3))

plt.plot(x3,avsum3,color="purple",label=("Double Agents Exploring (Modified)"))
plt.grid(color="blue")
plt.legend()
plt.grid(color="k")
plt.ylabel('Sum Squared Error (SSE)')
plt.xlabel('Episodes')
plt.title("Double Agent setting with only $Agent_1$ having power to end an episode")
plt.grid()
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 30

# %% [markdown]
# ##### Combined plot

# %%
A=plt.plot(x0,avsum0,color="b",label="Single agent E-greedy")
B=plt.plot(x1,avsum1,color="g",label="Single exploring agent")
C=plt.plot(x2,avsum2,color="r",label=("Double Agents"))
D=plt.plot(x3,avsum3,color="purple",label="Double Agents Modified")
#B=plt.plot(y,b,color="g")
A+B+C+D
plt.legend()
plt.grid(color="k")
plt.xlabel('Episodes')
plt.ylabel('Sum Squared Errors of Q-values')
plt.title("Comparison of all plots combined")
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 30

# %% [markdown]
# # Single agent plots with varying $\epsilon$

# %%
def E_comparison1(epsilon):
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    #N=50000
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode

       # print(S,A)
        while S!=(4,2) and S!=(4,3):

      #EXPLORATION ACTION
            if random.uniform(0,1)>1-epsilon:# exploration condition
                #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

                        
                        
            if random.uniform(0,1)<1-epsilon: #condition for exploitation

                #STATE(1,1)
                if S==(1,1):
                    c=ActionValues.index(max(ActionValues[:4])) #selecting the maximum action in state (1,1)
                    if c==0:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==1:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==2:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==3:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(1,1)

                #STATE(1,2)
                if S==(1,2):
                    c=ActionValues.index(max(ActionValues[4:8]))
                    if c==4:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                #STATE(1,3)
                if S==(1,3):
                    c=ActionValues.index(max(ActionValues[8:12]))
                    if c==8:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                #STATE(2,3)
                if S==(2,3):
                    c=ActionValues.index(max(ActionValues[12:16]))
                    if c==12:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==13:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==14:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==15:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                #STATE(2,1)
                if S==(2,1):
                    c=ActionValues.index(max(ActionValues[16:20]))
                    if c==16:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==17:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==18:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[c])
                        S=(1,1)

                    if c==19:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)


                #STATE(3,1)
                if S==(3,1):
                    c=ActionValues.index(max(ActionValues[20:24]))
                    if c==20:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==21:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==22:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==22:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(4,1)


                #STATE(3,2)
                if S==(3,2):
                    c=ActionValues.index(max(ActionValues[24:28]))
                    if c==24:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==25:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==26:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==27:#right
                        # the q values of terminal states are all 0's
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                #STATE(3,3)
                if S==(3,3):
                    c=ActionValues.index(max(ActionValues[28:32]))
                    if c==28:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==29:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==30:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==31:#right
                        ActionValues[c]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,1)


                #STATE(4,1)
                if S==(4,1):
                    c=ActionValues.index(max(ActionValues[32:]))
                    if c==32:#up
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                    if c==33:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)

                    if c==34:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==35:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)
        
                        
                

    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return ActionValues

# %%
t=E_comparison1(0.9)
# Out:
# Runtime of the program is 3.430565357208252

# %%
def E_comparison2(epsilon):
    #N=50000
    #epsilon=0.9
    ActionValues=[round(random.uniform(0.1,0.3),4) for i in range(len(States)*4)]
    sum_mse=[]
    #ss.append(sum_mse)
    start = time.time()
    for i in range(N):
        S=random.choice(States) #initialising the statrting state for each episode
        
       # print(S,A)
        while S!=(4,2) and S!=(4,3):
                #finding the sum squared error to come up with 1 plot from 36 different Q-values
            sum_mse.append(((ActionValues[0]-t[0])**2+(ActionValues[1]-t[1])**2+(ActionValues[2]-t[2])**2+(ActionValues[3]-t[3])**2
    +(ActionValues[4]-t[4])**2+(ActionValues[5]-t[5])**2+(ActionValues[6]-t[6])**2+(ActionValues[7]-t[7])**2
    +(ActionValues[8]-t[8])**2+(ActionValues[9]-t[9])**2+(ActionValues[10]-t[10])**2+(ActionValues[11]-t[11])**2
    +(ActionValues[12]-t[12])**2+(ActionValues[3]-t[13])**2+(ActionValues[14]-t[14])**2+(ActionValues[15]-t[15])**2
    +(ActionValues[16]-t[16])**2+(ActionValues[17]-t[17])**2+(ActionValues[18]-t[18])**2+(ActionValues[19]-t[19])**2
    +(ActionValues[20]-t[20])**2+(ActionValues[21]-t[21])**2+(ActionValues[22]-t[22])**2+(ActionValues[23]-t[23])**2
    +(ActionValues[24]-t[24])**2+(ActionValues[25]-t[25])**2+(ActionValues[26]-t[26])**2+(ActionValues[27]-t[27])**2
    +(ActionValues[28]-t[28])**2+(ActionValues[29]-t[29])**2+(ActionValues[30]-t[30])**2+(ActionValues[31]-t[31])**2
    +(ActionValues[32]-t[32])**2+(ActionValues[33]-t[33])**2+(ActionValues[34]-t[34])**2+(ActionValues[35]-t[35])**2
    ))





      #EXPLORATION ACTION
            if random.uniform(0,1)>1-epsilon:# exploration condition
                #EXPLORATION ACTION
            #if random.uniform(0,1)>1-epsilon:# exploration condition
                A=random.choice(Actions)     #selecting a random action 
    #STATE (1,1)##########################################################################

                if S==(1,1):
                    if A=='U':
                        ActionValues[0]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[0]) #Q-learning update rule
                        S=(1,2)

                    elif A=='D':
                        ActionValues[1]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[1])

                        S=(1,1)

                    elif A=='L':
                        ActionValues[2]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[2])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[3]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[3])
                        S=(2,1)

                #STATE (1,2)###############################################################

                elif S==(1,2):
                    if A=='U':
                        ActionValues[4]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[4])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[5]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[5])
                        S=(1,1)

                    elif A=='L':
                        ActionValues[6]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[6])
                        S=(1,2)

                    elif A=='R':
                        ActionValues[7]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[7])
                        S=(2,1)

                #STATE (1,3)#################################################################

                elif S==(1,3):
                    if A=='U':
                        ActionValues[8]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[8])
                        S=(1,3)

                    elif A=='D':
                        ActionValues[9]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[9])
                        S=(1,2)

                    elif A=='L':
                        ActionValues[10]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[10])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[11]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[11])
                        S=(2,3)

                #STATE (2,1)##################################################################
                elif S==(2,1):
                    if A=='U':
                        ActionValues[16]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[16])
                        S=(2,1)

                    elif A=='D':
                        ActionValues[17]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[17])
                        S=(2,1)

                    elif A=='L':
                        ActionValues[18]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[18])
                        S=(1,1)

                    elif A=='R':
                        ActionValues[19]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[19])
                        S=(3,1)

                #STATE (2,3)#####################################################################
                elif S==(2,3):
                    if A=='U':
                        ActionValues[12]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[12])
                        S=(2,3)

                    elif A=='D':
                        ActionValues[13]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[13])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[14]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[14])
                        S=(1,3)

                    elif A=='R':
                        ActionValues[15]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[15])
                        S=(3,3)

                #STATE (3,1)#######################################################################


                elif S==(3,1):
                    if A=='U':
                        ActionValues[20]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[20])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[21]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[21])
                        S=(2,3)

                    elif A=='L':
                        ActionValues[22]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[22])
                        S=(2,1)

                    elif A=='R':
                        ActionValues[23]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[23])
                        S=(4,1)

                #STATE (3,2)#####################################################################


                elif S==(3,2):
                    if A=='U':
                        ActionValues[24]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[24])
                        S=(3,2)

                    elif A=='D':
                        ActionValues[25]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[25])

                        S=(2,1)

                    elif A=='L':
                        ActionValues[26]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[26])

                        S=(3,2)

                    elif A=='R':
                        ActionValues[27]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[27])

                        S=(4,2)

                #STATE (3,3)########################################################################


                elif S==(3,3):
                    if A=='U':
                        ActionValues[28]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[28])

                        S=(3,3)

                    elif A=='D':
                        ActionValues[29]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[29])

                        S=(3,2)

                    elif A=='L':
                        ActionValues[30]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[30])

                        S=(2,3)

                    elif A=='R':
                        ActionValues[31]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[31])
                        S=(4,3)

                #STATE (4,1)#######################################################################
                elif S==(4,1):
                    if A=='U':
                        ActionValues[32]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[32])
                        S=(4,2)

                    elif A=='D':
                        ActionValues[33]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[33])
                        S=(4,1)

                    elif A=='L':
                        ActionValues[34]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[34])

                        S=(3,1)

                    elif A=='R':
                        ActionValues[35]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[35])

                        S=(4,1)

                        
                        
            if random.uniform(0,1)<1-epsilon: #condition for exploitation

                #STATE(1,1)
                if S==(1,1):
                    c=ActionValues.index(max(ActionValues[:4])) #selecting the maximum action in state (1,1)
                    if c==0:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==1:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==2:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==3:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(1,1)

                #STATE(1,2)
                if S==(1,2):
                    c=ActionValues.index(max(ActionValues[4:8]))
                    if c==4:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[0:4])-ActionValues[c])
                        S=(1,1)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                #STATE(1,3)
                if S==(1,3):
                    c=ActionValues.index(max(ActionValues[8:12]))
                    if c==8:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==5:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[4:8])-ActionValues[c])
                        S=(1,2)

                    if c==6:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==7:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                #STATE(2,3)
                if S==(2,3):
                    c=ActionValues.index(max(ActionValues[12:16]))
                    if c==12:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==13:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==14:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[8:12])-ActionValues[c])
                        S=(1,3)

                    if c==15:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                #STATE(2,1)
                if S==(2,1):
                    c=ActionValues.index(max(ActionValues[16:20]))
                    if c==16:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==17:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==18:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[:4])-ActionValues[c])
                        S=(1,1)

                    if c==19:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)


                #STATE(3,1)
                if S==(3,1):
                    c=ActionValues.index(max(ActionValues[20:24]))
                    if c==20:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==21:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==22:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[16:20])-ActionValues[c])
                        S=(2,1)

                    if c==22:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(4,1)


                #STATE(3,2)
                if S==(3,2):
                    c=ActionValues.index(max(ActionValues[24:28]))
                    if c==24:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==25:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==26:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==27:#right
                        # the q values of terminal states are all 0's
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                #STATE(3,3)
                if S==(3,3):
                    c=ActionValues.index(max(ActionValues[28:32]))
                    if c==28:#up
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[28:32])-ActionValues[c])
                        S=(3,3)

                    if c==29:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[24:28])-ActionValues[c])
                        S=(3,2)

                    if c==30:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[12:16])-ActionValues[c])
                        S=(2,3)

                    if c==31:#right
                        ActionValues[c]+=alpha*(R+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,1)


                #STATE(4,1)
                if S==(4,1):
                    c=ActionValues.index(max(ActionValues[32:]))
                    if c==32:#up
                        ActionValues[c]+=alpha*(Rr+gamma*max(0,0,0,0)-ActionValues[c])
                        S=(4,2)

                    if c==33:#down
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)

                    if c==34:#left
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[20:24])-ActionValues[c])
                        S=(3,1)

                    if c==35:#right
                        ActionValues[c]+=alpha*(r+gamma*max(ActionValues[32:])-ActionValues[c])
                        S=(4,1)
        
    #epsilon*=0.99
    time.sleep(1)
    end = time.time()
    print(f"Runtime of the program is {end - start}")
    return sum_mse

# %%
lp1=E_comparison2(0.1)
lp2=E_comparison2(0.2)
lp3=E_comparison2(0.3)
lp4=E_comparison2(0.4)
lp5=E_comparison2(0.5)
lp6=E_comparison2(0.6)
lp7=E_comparison2(0.7)
lp8=E_comparison2(0.8)
lp9=E_comparison2(0.9)
#lp10=E_comparison2(1.0)
# Out:
# Runtime of the program is 54.87595272064209
# Runtime of the program is 25.79712986946106
# Runtime of the program is 36.825268030166626
# Runtime of the program is 9.787034273147583
# Runtime of the program is 8.78780484199524
# Runtime of the program is 9.67804503440857
# Runtime of the program is 8.02029299736023
# Runtime of the program is 7.397426128387451
# Runtime of the program is 8.140484094619751

# %%
len(lp1)
# Out:
# 4874057

# %%
L1=np.linspace(0,N,len(lp1))
L2=np.linspace(0,N,len(lp2))
L3=np.linspace(0,N,len(lp3))
L4=np.linspace(0,N,len(lp4))
L5=np.linspace(0,N,len(lp5))
L6=np.linspace(0,N,len(lp6))
L7=np.linspace(0,N,len(lp7))
L8=np.linspace(0,N,len(lp8))
L9=np.linspace(0,N,len(lp9))
#L10=np.linspace(0,lp10[1],len(lp10[0]))

# %%
len(L1)
# Out:
# 4874057

# %%
X1=plt.plot(L1,lp1,label="$\epsilon=0.1$")
X2=plt.plot(L2,lp2,label="$\epsilon=0.2$")
X3=plt.plot(L3,lp3,label="$\epsilon=0.3$")
X4=plt.plot(L4,lp4,label="$\epsilon=0.4$")
X5=plt.plot(L5,lp5,label="$\epsilon=0.5$")
X6=plt.plot(L6,lp6,label="$\epsilon=0.6$")
X7=plt.plot(L7,lp7,label="$\epsilon=0.7$")
X8=plt.plot(L8,lp8,label="$\epsilon=0.8$")
X9=plt.plot(L9,lp9,label="$\epsilon=0.9$")
#X10=plt.plot(L10,lp1,label="$\epsilon=1.0$")

X1+X2+X3+X4+X5+X6+X7+X8+X9


#B=plt.plot(y,b,color="g")
#A+B
#plt.xlabel('Runtime')
plt.xlabel('Episodes')
plt.ylabel('Sum Squared Errors of Q-values')
plt.legend()
plt.grid(color="k")
plt.title("Single Agent $\epsilon$-Greedy with varying $\epsilon$")
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['font.size'] = 30
# Out:
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
